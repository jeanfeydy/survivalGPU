# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def plot_selection(ax, df,error_type):

    means = df[error_type + "_mean"]
    n_patients = df["n_patients"]
    percentile_95 = df[error_type + "_95p"]
    print(percentile_95)
    percentile_5 = df[error_type + "_5p"]
    print(percentile_5)
    error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
    print(error_lower)
    error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
    print(error_upper)
    error = [error_lower, error_upper]  # Matplotlib needs error in this format
    print(error)


    ax.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)

def df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint):

    df_selected = df
    df_selected = df_selected[df_selected["n_patients"] <= max_patients]
    df_selected = df_selected[df_selected["n_patients"] >= min_patients]
    df_selected = df_selected[df_selected["nknots"] == nknots]
    df_selected = df_selected[df_selected["weight_function"] == weight_function]
    df_selected = df_selected[df_selected["constraint"] == constraint]
    df_selected = df_selected[df_selected["n_bootstraps"] == n_bootstraps]
   
    return df_selected

# %%
experiment_name = "experiment : 1000 patients to 10000 patients"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df.head()
# Out:
#                                                 path  n_patients  \
# 0  Simulation_results/experiment : 1000 patients ...         100
# 1  Simulation_results/experiment : 1000 patients ...         100
# 2  Simulation_results/experiment : 1000 patients ...         100
# 3  Simulation_results/experiment : 1000 patients ...         100
# 4  Simulation_results/experiment : 1000 patients ...         100
#
#       weight_function  n_bootstraps  nknots  cutoff constraint  \
# 0  exponential_weight          1000       1     180      Right
# 1  exponential_weight          1000       1     180        NaN
# 2  exponential_weight          1000       2     180      Right
# 3  exponential_weight          1000       2     180        NaN
# 4  exponential_weight          1000       3     180      Right
#
#    simulation_time  computation_time  sum_weight_diff_mean  \
# 0           0.5652          7.141639              0.686906
# 1           0.5652          8.479703              1.174226
# 2           0.5652          6.568385              0.911678
# 3           0.5652          9.296569              1.385726
# 4           0.5652          7.949182              1.288357
#
#    sum_weight_diff_95p  sum_weight_diff_5p  AUC_diff_mean  AUC_diff_95p  \
# 0             1.251118            0.254084       0.386410      0.970232
# 1             1.949507            0.576560       0.512464      1.275430
# 2             1.528953            0.407585       0.433571      1.069430
# 3             2.252992            0.718488       0.524162      1.281526
# 4             2.173603            0.574364       0.474571      1.185871
#
#    AUC_diff_5p
# 0     0.036685
# 1     0.033150
# 2     0.040614
# 3     0.041413
# 4     0.043419

# %%
# simulation time
import numpy as np
import matplotlib.ticker as mticker



analyzed_df = df[ df["n_bootstraps"] == 1000]
analyzed_df = analyzed_df[ analyzed_df["n_patients"]>= 1000]
analyzed_df = analyzed_df[ analyzed_df["nknots"] == 1]
analyzed_df = analyzed_df[ analyzed_df["constraint"] == "Right"]
analyzed_df


simulation_time = list(analyzed_df["simulation_time"])
print(simulation_time)
simulation_time_min = [x/60 for x in simulation_time]
n_patients = list(analyzed_df["n_patients"])

def custom_formatter(x, pos):
    return f"{int(x)}"


# plt.rc('axes.formatter', useoffset=False)
plt.scatter(n_patients,simulation_time_min)
plt.xscale('log')
plt.yscale('log')
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
# plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
plt.xlabel("Number of patients")
plt.ylabel("Simulation time (min)")
plt.title("Analysis of the simulation time")


plt.show()
# Out:
# [9.6943, 44.2503, 143.1007, 532.8799, 60910.7143]

# %%
# simulation time
import numpy as np
import matplotlib.ticker as mticker



analyzed_df = df[ df["n_bootstraps"] == 1000]
analyzed_df = analyzed_df[ analyzed_df["n_patients"]>= 1000]
analyzed_df = analyzed_df[ analyzed_df["nknots"] == 1]
analyzed_df = analyzed_df[ analyzed_df["constraint"] == "Right"]
analyzed_df


computation_time = list(analyzed_df["computation_time"])
print(computation_time)
computation_time_min = [x/60 for x in computation_time]
n_patients = list(analyzed_df["n_patients"])

def custom_formatter(x, pos):
    return f"{int(x)}"


# plt.rc('axes.formatter', useoffset=False)
plt.scatter(n_patients,computation_time_min)
plt.xscale('log')
plt.yscale('log')
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
# plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
plt.xlabel("Number of patients")
plt.ylabel("Computation time (min)")
plt.title("Analysis of the computation time")

plt.show()
# Out:
# [12.100879907608032, 21.23461127281189, 34.65624809265137, 69.72241687774658, 1834.291969537735]

# %%
# simulation time
import numpy as np

analyzed_df = df[ df["n_bootstraps"] == 1000]
analyzed_df = analyzed_df[ analyzed_df["nknots"] == 1]
analyzed_df = analyzed_df[ analyzed_df["constraint"] == "Right"]
analyzed_df


computation_time = list(analyzed_df["computation_time"])
print(computation_time)
computation_time_min = [x/60 for x in computation_time]
n_patients = list(analyzed_df["n_patients"])

plt.plot(n_patients,computation_time_min)
plt.xscale('log')
plt.show()
# Out:
# [7.141638994216919, 6.122503042221069, 7.439655303955078, 12.100879907608032, 21.23461127281189, 34.65624809265137, 69.72241687774658, 1834.291969537735]

# %%
analyzed_df = df[df["nknots"] == 1]

means = analyzed_df["weight_diff_mean"]
n_patients = analyzed_df["n_patients"]
percentile_95 = analyzed_df["weight_diff_95p"]
percentile_5 = analyzed_df["weight_diff_5p"]
error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
error = [error_lower, error_upper]  # Matplotlib needs error in this format



plt.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)
plt.xlabel('number of patients')
plt.ylabel('Mean Value')
plt.title('Means for 1 knot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight_diff_mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9002/2971664986.py in <module>
#       1 analyzed_df = df[df["nknots"] == 1]
#       2
# ----> 3 means = analyzed_df["weight_diff_mean"]
#       4 n_patients = analyzed_df["n_patients"]
#       5 percentile_95 = analyzed_df["weight_diff_95p"]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'weight_diff_mean'

# %%
analyzed_df = df[df["nknots"] == 3]

means = analyzed_df["air_diff_mean"]
n_patients = analyzed_df["n_patients"]
percentile_95 = analyzed_df["air_diff_95p"]
percentile_5 = analyzed_df["air_diff_5p"]
error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
error = [error_lower, error_upper]  # Matplotlib needs error in this format



plt.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)
plt.xlabel('Number of patients')
plt.ylabel('Mean Value')
plt.title('Means with 5th and 95th Percentile Error Bars')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'air_diff_mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9002/1023881302.py in <module>
#       1 analyzed_df = df[df["nknots"] == 3]
#       2
# ----> 3 means = analyzed_df["air_diff_mean"]
#       4 n_patients = analyzed_df["n_patients"]
#       5 percentile_95 = analyzed_df["air_diff_95p"]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'air_diff_mean'

# %%
df_1_2 = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv")
df_1_2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9002/3059731980.py in <module>
# ----> 1 df_1_2 = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv")
#       2 df_1_2
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# --> 948     return _read(filepath_or_buffer, kwds)
#     949
#     950
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1703                 if "b" not in mode:
#    1704                     mode += "b"
# -> 1705             self.handles = get_handle(
#    1706                 f,
#    1707                 mode,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861         if ioargs.encoding and "b" not in ioargs.mode:
#     862             # Encoding
# --> 863             handle = open(
#     864                 handle,
#     865                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv'

# %%
df_1_2[df_1_2["n_patients"] < 1000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9002/2705500398.py in <module>
# ----> 1 df_1_2[df_1_2["n_patients"] < 1000]
#
# NameError: name 'df_1_2' is not defined

# %%
min_patients = 100
max_patients = 5000
nknots = 1
function = "exponential_weight"

# %%
means = df["air_diff_mean"]
n_patients = df["n_patients"]
percentile_95 = df["air_diff_95p"]
percentile_5 = df["air_diff_5p"]
error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
error = [error_lower, error_upper]  # Matplotlib needs error in this format



plt.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)
plt.xlabel('Number of patients')
plt.ylabel('Mean Value')
plt.title('Means with 5th and 95th Percentile Error Bars')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'air_diff_mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9002/1469260639.py in <module>
# ----> 1 means = df["air_diff_mean"]
#       2 n_patients = df["n_patients"]
#       3 percentile_95 = df["air_diff_95p"]
#       4 percentile_5 = df["air_diff_5p"]
#       5 error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'air_diff_mean'

# %%
means = df["weight_diff_mean"]
n_patients = df["n_patients"]
percentile_95 = df["weight_diff_95p"]
percentile_5 = df["weight_diff_5p"]
error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
error = [error_lower, error_upper]  # Matplotlib needs error in this format



plt.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)
plt.xlabel('Number of patients')
plt.ylabel('Mean Value')
plt.title('Means with 5th and 95th Percentile Error Bars')
plt.show()

# %%
def print_graph(ax, df,error_type):

    means = df[error_type + "_mean"]
    n_patients = df["n_patients"]
    percentile_95 = df[error_type + "_95p"]
    percentile_5 = df[error_type + "_5p"]
    error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
    error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
    error = [error_lower, error_upper]  # Matplotlib needs error in this format



    ax.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)
    ax.set_xticks(n_patients)
    ax.set_xlabel('Number of patients')
    ax.set_ylabel(error_type)
    ax.set_title(error_type)
    return ax

def df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint):

    df_selected = df
    df_selected = df_selected[df_selected["n_patients"] <= max_patients]
    df_selected = df_selected[df_selected["n_patients"] >= min_patients]
    df_selected = df_selected[df_selected["nknots"] == nknots]
    df_selected = df_selected[df_selected["weight_function"] == weight_function]
    df_selected = df_selected[df_selected["n_bootstraps"] == n_bootstraps]
    df_selected = df_selected[df_selected["constraint"] == constraint]

   
    return df_selected

# %%
min_patients = 20
max_patients = 100
nknots = 1
weight_function = "exponential_weight"

error_type = "weight_diff"

df = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv")
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function)
print_graph(df_selected, error_type)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9002/508165444.py in <module>
#       6 error_type = "weight_diff"
#       7
# ----> 8 df = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv")
#       9 df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function)
#      10 print_graph(df_selected, error_type)
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# --> 948     return _read(filepath_or_buffer, kwds)
#     949
#     950
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1703                 if "b" not in mode:
#    1704                     mode += "b"
# -> 1705             self.handles = get_handle(
#    1706                 f,
#    1707                 mode,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861         if ioargs.encoding and "b" not in ioargs.mode:
#     862             # Encoding
# --> 863             handle = open(
#     864                 handle,
#     865                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv'

# %%
min_patients = 100
max_patients = 5000
nknots = 1
weight_function = "exponential_weight"
n_bootstraps = 1000
constraint = "Right"

error_type = "weight_diff"

df = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/exponential_weight 100 - 100 000/exponential_weight 100 - 100 000.csv")
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function, n_bootstraps=n_bootstraps,constraint=constraint)
print_graph(df_selected, error_type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9002/2348621107.py in <module>
#       9
#      10 df = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/exponential_weight 100 - 100 000/exponential_weight 100 - 100 000.csv")
# ---> 11 df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function, n_bootstraps=n_bootstraps,constraint=constraint,error_type = error_type)
#      12 print_graph(df_selected, error_type)
#
# TypeError: df_selector() got an unexpected keyword argument 'error_type'

# %%
min_patients = 20
max_patients = 100
nknots = 1
weight_function = "bi_linear_weight"

error_type = "weight_diff"

df = pd.read_csv("/home/apoirotb/dev/Inria/survivalGPU/simulations/Simulation_results/18-01-2023/analyzed_18-01-2023.csv")
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function)
print_graph(df_selected, error_type)

# %%
def plot_selection(ax, df,error_type):

    means = df[error_type + "_mean"]
    n_patients = df["n_patients"]
    percentile_95 = df[error_type + "_95p"]
    print(percentile_95)
    percentile_5 = df[error_type + "_5p"]
    print(percentile_5)
    error_lower = [mean - p5 for mean, p5 in zip(means, percentile_5)]
    print(error_lower)
    error_upper = [p95 - mean for mean, p95 in zip(means, percentile_95)]
    print(error_upper)
    error = [error_lower, error_upper]  # Matplotlib needs error in this format
    print(error)


    ax.errorbar(n_patients, means, yerr=error, fmt='o', capsize=5)

def df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint):

    df_selected = df
    df_selected = df_selected[df_selected["n_patients"] <= max_patients]
    df_selected = df_selected[df_selected["n_patients"] >= min_patients]
    df_selected = df_selected[df_selected["nknots"] == nknots]
    df_selected = df_selected[df_selected["weight_function"] == weight_function]
    df_selected = df_selected[df_selected["constraint"] == constraint]
    df_selected = df_selected[df_selected["n_bootstraps"] == n_bootstraps]
   
    return df_selected

# %%
experiment_name = "experiment : 1000 patients to 10000 patients"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")

plt.figure(figsize=(15, 5))






# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

ax1 = plt.subplot(1, 3, 1) 
plot_selection(ax1,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale("log")
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 1")

n_bootstraps = 1000
nknots = 2

ax2 = plt.subplot(1, 3, 2) 
plot_selection(ax2,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale("log")
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()

n_bootstraps = 1000
nknots = 2

ax2 = plt.subplot(1, 3, 3) 
plot_selection(ax2,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale("log")
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()

plt.show()
# Out:
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]

# %%
experiment_name = "experiment : 1000 patients to 10000 patients"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")

plt.figure(figsize=(15, 5))






# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

ax1 = plt.subplot(1, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax1,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale('log')
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 1")

n_bootstraps = 1000
nknots = 2

ax2 = plt.subplot(1, 3, 2) 
# plt.ylim(0, 1.3)
plot_selection(ax2,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale('log')
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()

n_bootstraps = 1000
nknots = 2

ax2 = plt.subplot(1, 3, 3) 
# plt.ylim(0, 1.3)
plot_selection(ax2,df_selected,"AUC_diff")
plt.xscale('log')
plt.yscale('log')

plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()

plt.show()
# Out:
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]
# 0     0.970232
# 12    0.669704
# 24    0.372098
# 36    0.258816
# 48    0.203438
# 60    0.158931
# 72    0.071874
# 84    0.053210
# Name: AUC_diff_95p, dtype: float64
# 0     0.036685
# 12    0.026529
# 24    0.012814
# 36    0.008790
# 48    0.008858
# 60    0.005978
# 72    0.002245
# 84    0.014244
# Name: AUC_diff_5p, dtype: float64
# [0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297]
# [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]
# [[0.3497252421594178, 0.26686894963867036, 0.1348077689564194, 0.0948970840553701, 0.084908061719092, 0.0683191538952018, 0.0263139971997598, 0.019375601828507297], [0.58382203831648, 0.3763065151577664, 0.2244762432738893, 0.1551283485427884, 0.10967177365170129, 0.08463358379044181, 0.04331527757441529, 0.019591105625813905]]

# %%
experiment_name = "experiment : 1000 patients to 10000 patients"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df.fillna
# Out:
#                                                  path  n_patients  \
# 0   Simulation_results/experiment : 1000 patients ...         100
# 1   Simulation_results/experiment : 1000 patients ...         100
# 2   Simulation_results/experiment : 1000 patients ...         100
# 3   Simulation_results/experiment : 1000 patients ...         100
# 4   Simulation_results/experiment : 1000 patients ...         100
# ..                                                ...         ...
# 80  Simulation_results/experiment : 1000 patients ...       10000
# 81  Simulation_results/experiment : 1000 patients ...       10000
# 82  Simulation_results/experiment : 1000 patients ...       10000
# 83  Simulation_results/experiment : 1000 patients ...       10000
# 84  Simulation_results/Test_simulation_only_100000...      100000
#
#        weight_function  n_bootstraps  nknots  cutoff constraint  \
# 0   exponential_weight          1000       1     180      Right
# 1   exponential_weight          1000       1     180       None
# 2   exponential_weight          1000       2     180      Right
# 3   exponential_weight          1000       2     180       None
# 4   exponential_weight          1000       3     180      Right
# ..                 ...           ...     ...     ...        ...
# 80  exponential_weight         10000       2     180      Right
# 81  exponential_weight         10000       2     180       None
# 82  exponential_weight         10000       3     180      Right
# 83  exponential_weight         10000       3     180       None
# 84  exponential_weight          1000       1     180      Right
#
#     simulation_time  computation_time  sum_weight_diff_mean  \
# 0            0.5652          7.141639              0.686906
# 1            0.5652          8.479703              1.174226
# 2            0.5652          6.568385              0.911678
# 3            0.5652          9.296569              1.385726
# 4            0.5652          7.949182              1.288357
# ..              ...               ...                   ...
# 80         532.8799        794.180687              0.118864
# 81         532.8799       1068.684029              0.135854
# 82         532.8799        927.372286              0.131168
# 83         532.8799       1207.850289              0.153551
# 84       60910.7143       1834.291970              0.087763
#
#     sum_weight_diff_95p  sum_weight_diff_5p  AUC_diff_mean  AUC_diff_95p  \
# 0              1.251118            0.254084       0.386410      0.970232
# 1              1.949507            0.576560       0.512464      1.275430
# 2              1.528953            0.407585       0.433571      1.069430
# 3              2.252992            0.718488       0.524162      1.281526
# 4              2.173603            0.574364       0.474571      1.185871
# ..                  ...                 ...            ...           ...
# 80             0.168989            0.076064       0.033504      0.080931
# 81             0.196267            0.082434       0.041125      0.099952
# 82             0.184937            0.083062       0.033985      0.082869
# 83             0.215491            0.096543       0.041510      0.100292
# 84             0.101008            0.076046       0.033619      0.053210
#
#     AUC_diff_5p
# 0      0.036685
# 1      0.033150
# 2      0.040614
# 3      0.041413
# 4      0.043419
# ..          ...
# 80     0.002627
# 81     0.003081
# 82     0.002686
# 83     0.003267
# 84     0.014244
#
# [85 rows x 15 columns]

# %%
experiment_name = "multiple weights, 100-100000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")

plt.figure(figsize=(15, 5))

# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)
print(df_selected)


ax1 = plt.subplot(1, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax1,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel("sum weight difference")
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

n_bootstraps = 1000
nknots = 1

ax2 = plt.subplot(1, 3, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax2,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel("sum weight difference")
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


n_bootstraps = 10000
nknots = 2

ax2 = plt.subplot(1, 3, 3) 
# plt.ylim(0, 1.3)

plot_selection(ax2,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel("AUC difference")
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

plt.show()
# Out:
#                                                  path  n_patients  \
# 1   Simulation_results/multiple weights, 100-10000...         100
# 7   Simulation_results/multiple weights, 100-10000...         500
# 13  Simulation_results/multiple weights, 100-10000...        1000
# 19  Simulation_results/multiple weights, 100-10000...        5000
# 25  Simulation_results/multiple weights, 100-10000...       10000
# 31  Simulation_results/multiple weights, 100-10000...       50000
# 37  Simulation_results/multiple weights, 100-10000...      100000
#
#        weight_function  n_bootstraps  nknots  cutoff constraint  \
# 1   exponential_weight          1000       1     180       None
# 7   exponential_weight          1000       1     180       None
# 13  exponential_weight          1000       1     180       None
# 19  exponential_weight          1000       1     180       None
# 25  exponential_weight          1000       1     180       None
# 31  exponential_weight          1000       1     180       None
# 37  exponential_weight          1000       1     180       None
#
#     computation_time  normalization  sum_weight_diff_mean  \
# 1           7.605846              1              1.440047
# 7          11.958124              1              0.488431
# 13         17.912133              1              0.398680
# 19         51.232923              1              0.246285
# 25        400.362368              1              0.140296
# 31       1495.305681              1              0.092580
# 37       2829.565797              1              0.079115
#
#     sum_weight_diff_95p  sum_weight_diff_5p  AUC_diff_mean  AUC_diff_95p  \
# 1              2.183414            0.827207       0.993682      1.650205
# 7              0.785140            0.233633       0.226853      0.526466
# 13             0.622016            0.211843       0.121668      0.303546
# 19             0.350412            0.143847       0.071945      0.164931
# 25             0.195447            0.092964       0.036328      0.086650
# 31             0.124373            0.062289       0.024015      0.055357
# 37             0.101865            0.057236       0.015530      0.036835
#
#     AUC_diff_5p
# 1      0.342287
# 7      0.021628
# 13     0.009838
# 19     0.005249
# 25     0.002717
# 31     0.001591
# 37     0.001502
# 1     2.183414
# 7     0.785140
# 13    0.622016
# 19    0.350412
# 25    0.195447
# 31    0.124373
# 37    0.101865
# Name: sum_weight_diff_95p, dtype: float64
# 1     0.827207
# 7     0.233633
# 13    0.211843
# 19    0.143847
# 25    0.092964
# 31    0.062289
# 37    0.057236
# Name: sum_weight_diff_5p, dtype: float64
# [0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243]
# [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]
# [[0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243], [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]]
# 1     2.183414
# 7     0.785140
# 13    0.622016
# 19    0.350412
# 25    0.195447
# 31    0.124373
# 37    0.101865
# Name: sum_weight_diff_95p, dtype: float64
# 1     0.827207
# 7     0.233633
# 13    0.211843
# 19    0.143847
# 25    0.092964
# 31    0.062289
# 37    0.057236
# Name: sum_weight_diff_5p, dtype: float64
# [0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243]
# [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]
# [[0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243], [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]]
# 1     2.183414
# 7     0.785140
# 13    0.622016
# 19    0.350412
# 25    0.195447
# 31    0.124373
# 37    0.101865
# Name: sum_weight_diff_95p, dtype: float64
# 1     0.827207
# 7     0.233633
# 13    0.211843
# 19    0.143847
# 25    0.092964
# 31    0.062289
# 37    0.057236
# Name: sum_weight_diff_5p, dtype: float64
# [0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243]
# [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]
# [[0.6128397945165633, 0.2547978728115558, 0.18683716941624878, 0.10243743592500693, 0.047332822389900706, 0.030291061960160806, 0.021879568964243], [0.7433669027090073, 0.2967083812654017, 0.22333586301654573, 0.10412751278281207, 0.05515051721781489, 0.03179309915751219, 0.0227496276721358]]

# %%
experiment_name = "exponential_weight 100 - 100 000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")



# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

# analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plt.figure(figsize=(15, 10))

analytics = "AUC_diff"


ax= plt.subplot(2, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 3) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

analytics = "sum_weight_diff"



nknots = 1
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 4) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 5) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()

plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 6) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")



path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "exponential_weight_right_constrined"
plt.savefig(path + file_name, transparent = True)

plt.show()
# Out:
# 0     0.839537
# 6     0.307871
# 12    0.261896
# 18    0.109065
# 24    0.074696
# 30    0.092654
# 36    0.037894
# Name: AUC_diff_95p, dtype: float64
# 0     0.031485
# 6     0.010936
# 12    0.010398
# 18    0.004618
# 24    0.002699
# 30    0.035286
# 36    0.002691
# Name: AUC_diff_5p, dtype: float64
# [0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577]
# [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]
# [[0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577], [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]]
# 2     0.936791
# 8     0.357027
# 14    0.314534
# 20    0.115917
# 26    0.090408
# 32    0.095725
# 38    0.026501
# Name: AUC_diff_95p, dtype: float64
# 2     0.027169
# 8     0.012252
# 14    0.008869
# 20    0.003923
# 26    0.002241
# 32    0.036597
# 38    0.000913
# Name: AUC_diff_5p, dtype: float64
# [0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076]
# [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]
# [[0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076], [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]]
# 4     0.939394
# 10    0.373079
# 16    0.362493
# 22    0.130303
# 28    0.100878
# 34    0.082670
# 40    0.025012
# Name: AUC_diff_95p, dtype: float64
# 4     0.021900
# 10    0.011001
# 16    0.019185
# 22    0.003430
# 28    0.004544
# 34    0.022960
# 40    0.000722
# Name: AUC_diff_5p, dtype: float64
# [0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227]
# [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]
# [[0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227], [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]]
# 0     1.744794
# 6     0.454740
# 12    0.504438
# 18    0.217726
# 24    0.153044
# 30    0.111355
# 36    0.098362
# Name: sum_weight_diff_95p, dtype: float64
# 0     0.503414
# 6     0.106218
# 12    0.139160
# 18    0.078125
# 24    0.077703
# 30    0.059599
# 36    0.067896
# Name: sum_weight_diff_5p, dtype: float64
# [0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512]
# [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]
# [[0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512], [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]]
# 2     1.886732
# 8     0.637057
# 14    0.505319
# 20    0.235791
# 26    0.169295
# 32    0.115708
# 38    0.103552
# Name: sum_weight_diff_95p, dtype: float64
# 2     0.653476
# 8     0.178085
# 14    0.183464
# 20    0.089575
# 26    0.076982
# 32    0.062278
# 38    0.067120
# Name: sum_weight_diff_5p, dtype: float64
# [0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312]
# [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]
# [[0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312], [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]]
# 4     2.129603
# 10    0.635296
# 16    0.675164
# 22    0.317454
# 28    0.176059
# 34    0.120767
# 40    0.100525
# Name: sum_weight_diff_95p, dtype: float64
# 4     0.864064
# 10    0.218926
# 16    0.264383
# 22    0.138725
# 28    0.080254
# 34    0.069757
# 40    0.062819
# Name: sum_weight_diff_5p, dtype: float64
# [0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906]
# [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]
# [[0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906], [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]]

# %%
experiment_name = "exponential_weight 100 - 100 000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")



# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

# analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plt.figure(figsize=(15, 10))

analytics = "AUC_diff"


ax= plt.subplot(2, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 3) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

# analytics = "AUC_diff"



nknots = 1
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 4) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 5) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()

plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 6) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")



path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "logy_non_logy_comparison_AUC"
plt.savefig(path + file_name, transparent = True)

plt.show()
# Out:
# 0     0.839537
# 6     0.307871
# 12    0.261896
# 18    0.109065
# 24    0.074696
# 30    0.092654
# 36    0.037894
# Name: AUC_diff_95p, dtype: float64
# 0     0.031485
# 6     0.010936
# 12    0.010398
# 18    0.004618
# 24    0.002699
# 30    0.035286
# 36    0.002691
# Name: AUC_diff_5p, dtype: float64
# [0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577]
# [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]
# [[0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577], [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]]
# 2     0.936791
# 8     0.357027
# 14    0.314534
# 20    0.115917
# 26    0.090408
# 32    0.095725
# 38    0.026501
# Name: AUC_diff_95p, dtype: float64
# 2     0.027169
# 8     0.012252
# 14    0.008869
# 20    0.003923
# 26    0.002241
# 32    0.036597
# 38    0.000913
# Name: AUC_diff_5p, dtype: float64
# [0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076]
# [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]
# [[0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076], [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]]
# 4     0.939394
# 10    0.373079
# 16    0.362493
# 22    0.130303
# 28    0.100878
# 34    0.082670
# 40    0.025012
# Name: AUC_diff_95p, dtype: float64
# 4     0.021900
# 10    0.011001
# 16    0.019185
# 22    0.003430
# 28    0.004544
# 34    0.022960
# 40    0.000722
# Name: AUC_diff_5p, dtype: float64
# [0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227]
# [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]
# [[0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227], [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]]
# 0     0.839537
# 6     0.307871
# 12    0.261896
# 18    0.109065
# 24    0.074696
# 30    0.092654
# 36    0.037894
# Name: AUC_diff_95p, dtype: float64
# 0     0.031485
# 6     0.010936
# 12    0.010398
# 18    0.004618
# 24    0.002699
# 30    0.035286
# 36    0.002691
# Name: AUC_diff_5p, dtype: float64
# [0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577]
# [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]
# [[0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577], [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]]
# 2     0.936791
# 8     0.357027
# 14    0.314534
# 20    0.115917
# 26    0.090408
# 32    0.095725
# 38    0.026501
# Name: AUC_diff_95p, dtype: float64
# 2     0.027169
# 8     0.012252
# 14    0.008869
# 20    0.003923
# 26    0.002241
# 32    0.036597
# 38    0.000913
# Name: AUC_diff_5p, dtype: float64
# [0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076]
# [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]
# [[0.35545696521183007, 0.1401784697604615, 0.11305191952190789, 0.0428965033742477, 0.0350389188289386, 0.029770931299668096, 0.0095476469297076], [0.5541655349932756, 0.2045965095314925, 0.19261323732229968, 0.06909753007694891, 0.05312800264075689, 0.029356568795235197, 0.016040406852686602]]
# 4     0.939394
# 10    0.373079
# 16    0.362493
# 22    0.130303
# 28    0.100878
# 34    0.082670
# 40    0.025012
# Name: AUC_diff_95p, dtype: float64
# 4     0.021900
# 10    0.011001
# 16    0.019185
# 22    0.003430
# 28    0.004544
# 34    0.022960
# 40    0.000722
# Name: AUC_diff_5p, dtype: float64
# [0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227]
# [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]
# [[0.36549047831083187, 0.1422323052542507, 0.13481722473529578, 0.0496681467757344, 0.0369941168831866, 0.0295037136961104, 0.0097142250721227], [0.5520033432021396, 0.21984504031361202, 0.20849077427094093, 0.0772054280693009, 0.059339619860458506, 0.030207008843155796, 0.0145754624742088]]

# %%
experiment_name = "exponential_weight 100 - 100 000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")



# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

# analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plt.figure(figsize=(15, 10))

analytics = "sum_weight_diff"


ax= plt.subplot(2, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 3) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

analytics = "sum_weight_diff"



nknots = 1
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 4) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 1")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")

nknots = 2
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 5) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 2")
plt.tight_layout()

plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")


nknots = 3
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 6) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("nknot = 3")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")



path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "logy_non_logy_comparison_sum"
plt.savefig(path + file_name, transparent = True)

plt.show()
# Out:
# 0     1.744794
# 6     0.454740
# 12    0.504438
# 18    0.217726
# 24    0.153044
# 30    0.111355
# 36    0.098362
# Name: sum_weight_diff_95p, dtype: float64
# 0     0.503414
# 6     0.106218
# 12    0.139160
# 18    0.078125
# 24    0.077703
# 30    0.059599
# 36    0.067896
# Name: sum_weight_diff_5p, dtype: float64
# [0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512]
# [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]
# [[0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512], [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]]
# 2     1.886732
# 8     0.637057
# 14    0.505319
# 20    0.235791
# 26    0.169295
# 32    0.115708
# 38    0.103552
# Name: sum_weight_diff_95p, dtype: float64
# 2     0.653476
# 8     0.178085
# 14    0.183464
# 20    0.089575
# 26    0.076982
# 32    0.062278
# 38    0.067120
# Name: sum_weight_diff_5p, dtype: float64
# [0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312]
# [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]
# [[0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312], [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]]
# 4     2.129603
# 10    0.635296
# 16    0.675164
# 22    0.317454
# 28    0.176059
# 34    0.120767
# 40    0.100525
# Name: sum_weight_diff_95p, dtype: float64
# 4     0.864064
# 10    0.218926
# 16    0.264383
# 22    0.138725
# 28    0.080254
# 34    0.069757
# 40    0.062819
# Name: sum_weight_diff_5p, dtype: float64
# [0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906]
# [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]
# [[0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906], [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]]
# 0     1.744794
# 6     0.454740
# 12    0.504438
# 18    0.217726
# 24    0.153044
# 30    0.111355
# 36    0.098362
# Name: sum_weight_diff_95p, dtype: float64
# 0     0.503414
# 6     0.106218
# 12    0.139160
# 18    0.078125
# 24    0.077703
# 30    0.059599
# 36    0.067896
# Name: sum_weight_diff_5p, dtype: float64
# [0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512]
# [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]
# [[0.566357548266649, 0.1566544163636863, 0.1706847608312964, 0.06349201664328578, 0.03322092292457819, 0.021958751648664405, 0.014370532277971512], [0.6750231373012068, 0.1918674163855611, 0.19459352863579998, 0.076109463199973, 0.04211954960972071, 0.0297977799102664, 0.016095148827880698]]
# 2     1.886732
# 8     0.637057
# 14    0.505319
# 20    0.235791
# 26    0.169295
# 32    0.115708
# 38    0.103552
# Name: sum_weight_diff_95p, dtype: float64
# 2     0.653476
# 8     0.178085
# 14    0.183464
# 20    0.089575
# 26    0.076982
# 32    0.062278
# 38    0.067120
# Name: sum_weight_diff_5p, dtype: float64
# [0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312]
# [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]
# [[0.5922603668868544, 0.1899666593521834, 0.154664501696825, 0.06941901225596661, 0.042558970849961006, 0.024804841391742292, 0.0174804033823312], [0.6409949777424331, 0.269004439458251, 0.16719107761979096, 0.0767972390726209, 0.049754027102142606, 0.0286255016550421, 0.018950724031776195]]
# 4     2.129603
# 10    0.635296
# 16    0.675164
# 22    0.317454
# 28    0.176059
# 34    0.120767
# 40    0.100525
# Name: sum_weight_diff_95p, dtype: float64
# 4     0.864064
# 10    0.218926
# 16    0.264383
# 22    0.138725
# 28    0.080254
# 34    0.069757
# 40    0.062819
# Name: sum_weight_diff_5p, dtype: float64
# [0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906]
# [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]
# [[0.5993390127122402, 0.1910448917821049, 0.2030170428678394, 0.0848114886954427, 0.04461675428971641, 0.024307859059423204, 0.018966508448123906], [0.6662001267969608, 0.22532548441737887, 0.2077641335204244, 0.09391754700988528, 0.051188428763300195, 0.026702431846410093, 0.018739284411072796]]

# %%
experiment_name = "exponential_weight 100 - 100 000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")



# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"

# analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plt.figure(figsize=(10, 10))

analytics = "AUC_diff"
constraint = "Right"


ax= plt.subplot(2, 2, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("Right constrained 1 knot")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.001,2))


nknots = 1
analytics = "AUC_diff"
constraint = "None"

df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 2, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("Right constrained 2 knot")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.001,2))

constraint = "Right"

ax= plt.subplot(2, 2, 3) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("Right constrained 1 knot")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0,1.2))

nknots = 1
constraint = "None"

df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 2, 4) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
# plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("Right constrained 2 knot")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0,1.2))




path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "Righ_None_constrained"
plt.savefig(path + file_name, transparent = True)

plt.show()
# Out:
# 0     0.839537
# 6     0.307871
# 12    0.261896
# 18    0.109065
# 24    0.074696
# 30    0.092654
# 36    0.037894
# Name: AUC_diff_95p, dtype: float64
# 0     0.031485
# 6     0.010936
# 12    0.010398
# 18    0.004618
# 24    0.002699
# 30    0.035286
# 36    0.002691
# Name: AUC_diff_5p, dtype: float64
# [0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577]
# [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]
# [[0.3145565585145824, 0.1206039105498109, 0.0949520769036592, 0.0413945437470532, 0.0280318934239637, 0.029384900931907904, 0.0171685327187577], [0.4934954325733337, 0.17633096986052207, 0.15654589515718448, 0.0630523787344869, 0.043965215350566994, 0.027982244276133994, 0.018034041574302998]]
# 1     0.997761
# 7     0.390330
# 13    0.351792
# 19    0.143116
# 25    0.136720
# 31    0.073192
# 37    0.035516
# Name: AUC_diff_95p, dtype: float64
# 1     0.030109
# 7     0.016989
# 13    0.011123
# 19    0.005400
# 25    0.009149
# 31    0.005763
# 37    0.001184
# Name: AUC_diff_5p, dtype: float64
# [0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092]
# [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]
# [[0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092], [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]]
# 1     0.997761
# 7     0.390330
# 13    0.351792
# 19    0.143116
# 25    0.136720
# 31    0.073192
# 37    0.035516
# Name: AUC_diff_95p, dtype: float64
# 1     0.030109
# 7     0.016989
# 13    0.011123
# 19    0.005400
# 25    0.009149
# 31    0.005763
# 37    0.001184
# Name: AUC_diff_5p, dtype: float64
# [0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092]
# [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]
# [[0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092], [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]]
# 1     0.997761
# 7     0.390330
# 13    0.351792
# 19    0.143116
# 25    0.136720
# 31    0.073192
# 37    0.035516
# Name: AUC_diff_95p, dtype: float64
# 1     0.030109
# 7     0.016989
# 13    0.011123
# 19    0.005400
# 25    0.009149
# 31    0.005763
# 37    0.001184
# Name: AUC_diff_5p, dtype: float64
# [0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092]
# [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]
# [[0.3784026808636463, 0.14502342423710982, 0.1366063620026271, 0.05819519961651891, 0.0609233721852107, 0.033698180652696405, 0.0138066708235092], [0.5892488184859848, 0.228317402112958, 0.20406253182403258, 0.07952051377168759, 0.0666473705472853, 0.0337310218498388, 0.0205251107287731]]

# %%
experiment_name = "multiple weights : 100 - 10000"

df = pd.read_csv("../Simulation_results/" + experiment_name + "/" + "analyzed_" + experiment_name +".csv")
df = df.fillna("None")



# print(df.keys())

# print(df)



# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

# print(df_selected)
# ax1 = plt.subplot(2, 2, 1) 
# plot_selection(ax1,df_selected,"sum_weight_diff")
# ax2 = plt.subplot(2, 2, 3) 
# plot_selection(ax2,df_selected,"AUC_diff")


min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
constraint = "Right"




plt.figure(figsize=(15, 10))

analytics = "AUC_diff"

weight_function = "exponential_weight"

analytics = "sum_weight_diff"
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax= plt.subplot(2, 3, 1) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("exponential_weight")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.01,3))



weight_function = "bi_linear_weight"

df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)

ax = plt.subplot(2, 3, 2) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("bi_linear_weight")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.01,3))




weight_function = "early_peak_weight"

df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 3) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("early_peak_weight")
plt.tight_layout()
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.01,3))



weight_function = "inverted_u_weight"

df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 4) 
# plt.ylim(0, 1.3)
plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("inverted_u_weight")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.01,3))



weight_function = "null_weight"


df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


ax = plt.subplot(2, 3, 5) 
# plt.ylim(0, 1.3)

plot_selection(ax,df_selected,analytics)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(str(analytics))
plt.xlabel("Number of patients")
plt.title("null_weight")
plt.tight_layout()

plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.ylim((0.01,3))



# nknots = 3
# df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)


# ax = plt.subplot(2, 3, 6) 
# # plt.ylim(0, 1.3)

# plot_selection(ax,df_selected,analytics)
# plt.xscale('log')
# plt.yscale('log')
# plt.ylabel(str(analytics))
# plt.xlabel("Number of patients")
# plt.title("nknot = 3")
# plt.tight_layout()
# plt.grid(True, which="major", linestyle="-")
# plt.grid(True, which="minor", linestyle="dotted")



path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "fucked_up_shit"
plt.savefig(path + file_name, transparent = True)

plt.show()
plt.show()
# Out:
# 90    1.744794
# 91    0.504438
# 92    0.153044
# Name: sum_weight_diff_95p, dtype: float64
# 90    0.503414
# 91    0.139160
# 92    0.077703
# Name: sum_weight_diff_5p, dtype: float64
# [0.566357548266649, 0.1706847608312964, 0.03322092292457819]
# [0.6750231373012068, 0.19459352863579998, 0.04211954960972071]
# [[0.566357548266649, 0.1706847608312964, 0.03322092292457819], [0.6750231373012068, 0.19459352863579998, 0.04211954960972071]]
# 0     2.694850
# 30    1.232425
# 60    1.271504
# Name: sum_weight_diff_95p, dtype: float64
# 0     1.353254
# 30    0.906064
# 60    1.136579
# Name: sum_weight_diff_5p, dtype: float64
# [0.6519647965431214, 0.1485814106464387, 0.06553761696815474]
# [0.6896316280364987, 0.17777966737747186, 0.06938757562637332]
# [[0.6519647965431214, 0.1485814106464387, 0.06553761696815474], [0.6896316280364987, 0.17777966737747186, 0.06938757562637332]]
# 6     1.914210
# 12    1.914210
# 36    1.271472
# 42    1.271472
# 66    1.175500
# 72    1.175500
# Name: sum_weight_diff_95p, dtype: float64
# 6     0.738315
# 12    0.738315
# 36    0.902572
# 42    0.902572
# 66    1.044494
# 72    1.044494
# Name: sum_weight_diff_5p, dtype: float64
# [0.5317563871741294, 0.5317563871741294, 0.16264254289865487, 0.16264254289865487, 0.06740096300840381, 0.06740096300840381]
# [0.644139288842678, 0.644139288842678, 0.20625806313753148, 0.20625806313753148, 0.06360569506883618, 0.06360569506883618]
# [[0.5317563871741294, 0.5317563871741294, 0.16264254289865487, 0.16264254289865487, 0.06740096300840381, 0.06740096300840381], [0.644139288842678, 0.644139288842678, 0.20625806313753148, 0.20625806313753148, 0.06360569506883618, 0.06360569506883618]]
# 18    2.018024
# 48    1.005512
# 78    0.972124
# Name: sum_weight_diff_95p, dtype: float64
# 18    0.929649
# 48    0.738196
# 78    0.886508
# Name: sum_weight_diff_5p, dtype: float64
# [0.49449997764825826, 0.12991881972551345, 0.04166934156417845]
# [0.593875459611416, 0.13739708656072602, 0.043946934103965773]
# [[0.49449997764825826, 0.12991881972551345, 0.04166934156417845], [0.593875459611416, 0.13739708656072602, 0.043946934103965773]]
# 24    1.220774
# 54    0.358300
# 84    0.124619
# Name: sum_weight_diff_95p, dtype: float64
# 24    0.251122
# 54    0.068030
# 84    0.028582
# Name: sum_weight_diff_5p, dtype: float64
# [0.42494190684705974, 0.12693035217560822, 0.045132154714316204]
# [0.54470993899554, 0.1633392156418412, 0.05090432555973519]
# [[0.42494190684705974, 0.12693035217560822, 0.045132154714316204], [0.54470993899554, 0.1633392156418412, 0.05090432555973519]]

# %%
# simulation time
import numpy as np
import matplotlib.ticker as mticker



min_patients = 100
max_patients = 100000
n_bootstraps = 1000
nknots = 1
weight_function = "exponential_weight"
constraint = "Right"

# analytics = "AUC_diff"
analytics = "sum_weight_diff"

max_patients = 100000
df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)
df_selected = df_selected[df_selected["n_patients"].isin([100,1000,10000,100000])]


computation_time = list(df_selected["computation_time"])
print(computation_time)
computation_time_min = [x for x in computation_time]
n_patients = list(df_selected["n_patients"])

def custom_formatter(x, pos):
    return f"{int(x)}"

R_computation_time = [100,4000,120000]


n_patients_2 = [100,1000,10000]


# plt.rc('axes.formatter', useoffset=False)
plt.scatter(n_patients,computation_time_min)
plt.scatter(n_patients_2,R_computation_time)
plt.xscale('log')
plt.yscale('log')
# plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
# plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
plt.xlabel("Number of patients")
plt.ylabel("Computation time (sec)")
plt.title("Analysis of the computation time")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
# plt.figure(figsize=(12, 8))
plt.savefig('test.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      15 analytics = "sum_weight_diff"
#      17 max_patients = 100000
# ---> 18 df_selected = df_selector(df,min_patients,max_patients,nknots,weight_function,n_bootstraps,constraint)
#      19 df_selected = df_selected[df_selected["n_patients"].isin([100,1000,10000,100000])]
#      22 computation_time = list(df_selected["computation_time"])
#
# NameError: name 'df_selector' is not defined

# %%
import json 

file_name = "100-1000 no bootstraps"

path = "../Simulation_results/Computation_time_comprison/" + file_name + ".json"

data_json = open(path)
data = json.load(data_json)
# print(data)


# simulation time
import numpy as np
import matplotlib.ticker as mticker





n_patients_list = [100,1000,10000,100000]
GPU_computaiton_time = []
CPU_computaiton_time = []
for n in n_patients_list:
    GPU_computaiton_time.append(data["GPU_computaiton_time"][str(n)][0])
    CPU_computaiton_time.append(data["CPU_computation_time"][str(n)][0])

print(GPU_computaiton_time)
print(CPU_computaiton_time)

GPU_computaiton_time[0] = 0.4944
print(GPU_computaiton_time)



# plt.rc('axes.formatter', useoffset=False)
plt.scatter(n_patients_list,GPU_computaiton_time)
plt.scatter(n_patients_list,CPU_computaiton_time)
plt.xscale('log')
plt.yscale('log')
# plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
# plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
plt.xlabel("Number of patients")
plt.ylabel("Computation time (sec)")
plt.title("Computation time without bootstraps")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.legend(["SurvivalGPU","Rsurvival"])
# plt.figure(figsize=(12, 8))

path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "computation_time_without_bootstraps"
plt.savefig(path + file_name, transparent = True)
# Out:
# [8.8538, 0.7879, 2.8243, 22.2689]
# [0.0951, 3.6065, 120.028, 10668.6639]
# [0.4944, 0.7879, 2.8243, 22.2689]

# %%
import json 

file_name = "100-1000 with bootstraps"

path = "../Simulation_results/Computation_time_comprison/" + file_name + ".json"

data_json = open(path)
data = json.load(data_json)
# print(data)


# simulation time
import numpy as np
import matplotlib.ticker as mticker





# n_patients_list = [100,1000,10000]
# GPU_computaiton_time = []
# CPU_computaiton_time = []
# for n in n_patients_list:
#     GPU_computaiton_time.append(data["GPU_computaiton_time"][str(n)][0])
#     CPU_computaiton_time.append(data["CPU_computation_time"][str(n)][0])

# print(GPU_computaiton_time)
# print(CPU_computaiton_time)

GPU_computaiton_time = [7.5245,15.7582,94.3655]
CPU_computaiton_time = [75.744,3068.077]


# plt.rc('axes.formatter', useoffset=False)
n_patients_list = [100,1000,10000]
plt.scatter(n_patients_list,GPU_computaiton_time)
n_patients_list = [100,1000]
plt.scatter(n_patients_list,CPU_computaiton_time)
plt.xscale('log')
plt.yscale('log')
# plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
# plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(custom_formatter))
plt.xlabel("Number of patients")
plt.ylabel("Computation time (sec)")
plt.title("Computation time with 1000 bootstraps")
plt.grid(True, which="major", linestyle="-")
plt.grid(True, which="minor", linestyle="dotted")
plt.legend(["SurvivalGPU","Rsurvival"])
# plt.figure(figsize=(12, 8))

path = '/home/apoirotb/dev/Inria/Notes/Slides /Meeting 27-02-2024/images/'
file_name = "computation_time_with_bootstraps"
plt.savefig(path + file_name, transparent = True)
