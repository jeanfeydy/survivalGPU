# %%
pip install scikit-survival
# Out:
# Collecting scikit-survival
#   Downloading scikit_survival-0.22.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 1.7 MB/s eta 0:00:00
# Collecting ecos (from scikit-survival)
#   Downloading ecos-2.0.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Collecting joblib (from scikit-survival)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numexpr (from scikit-survival)
#   Downloading numexpr-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from scikit-survival) (1.26.2)
# Collecting osqp!=0.6.0,!=0.6.1 (from scikit-survival)
#   Downloading osqp-0.6.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: pandas>=1.0.5 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from scikit-survival) (2.1.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from scikit-survival) (1.13.0)
# Collecting scikit-learn<1.4,>=1.3.0 (from scikit-survival)
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting qdldl (from osqp!=0.6.0,!=0.6.1->scikit-survival)
#   Downloading qdldl-0.1.7.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from pandas>=1.0.5->scikit-survival) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from pandas>=1.0.5->scikit-survival) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from pandas>=1.0.5->scikit-survival) (2023.4)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn<1.4,>=1.3.0->scikit-survival)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /home/apoirotb/dev/Inria/survivalGPU/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->scikit-survival) (1.16.0)
# Downloading scikit_survival-0.22.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 14.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading osqp-0.6.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.0/299.0 kB 14.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 14.7 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 14.1 MB/s eta 0:00:00
# Downloading ecos-2.0.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 14.8 MB/s eta 0:00:00
# Downloading numexpr-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.1/376.1 kB 15.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading qdldl-0.1.7.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: threadpoolctl, numexpr, joblib, scikit-learn, qdldl, ecos, osqp, scikit-survival
# Successfully installed ecos-2.0.13 joblib-1.4.2 numexpr-2.10.0 osqp-0.6.7 qdldl-0.1.7.post2 scikit-learn-1.3.2 scikit-survival-0.22.2 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sksurv.datasets import load_breast_cancer
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.preprocessing import OneHotEncoder

from sklearn import set_config
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

X, y = load_breast_cancer()
Xt = OneHotEncoder().fit_transform(X)
Xt.round(2).head()
# Out:
#    X200726_at  X200965_s_at  X201068_s_at  X201091_s_at  X201288_at  \
# 0       10.93          8.96         11.63         10.96       11.52
# 1       12.24          9.53         12.63         11.59       12.32
# 2       11.66         10.24         12.57          9.17       11.70
# 3       12.17          9.82         12.11          9.09       13.13
# 4       11.48         11.49         11.78          8.89       10.43
#
#    X201368_at  X201663_s_at  X201664_at  X202239_at  X202240_at  ...  \
# 0       12.04          9.62        9.81       10.02        7.85  ...
# 1       10.78         10.60       10.70       10.16        8.74  ...
# 2       11.35          9.38       10.16       10.03        8.13  ...
# 3       11.86          8.40        8.67       10.73        8.65  ...
# 4       11.40          7.74        8.64        9.56        8.48  ...
#
#    X221816_s_at  X221882_s_at  X221916_at  X221928_at   age  er=positive  \
# 0         10.13         10.93        6.48        5.99  57.0          0.0
# 1         10.21          9.56        4.97        7.05  57.0          1.0
# 2         10.16          9.31        4.28        6.83  48.0          0.0
# 3         10.66         10.21        5.71        6.93  42.0          1.0
# 4         11.57         10.93        5.82        6.66  46.0          1.0
#
#    grade=intermediate  grade=poorly differentiated  grade=unkown  size
# 0                 0.0                          1.0           0.0   3.0
# 1                 0.0                          1.0           0.0   3.0
# 2                 0.0                          1.0           0.0   2.5
# 3                 0.0                          1.0           0.0   1.8
# 4                 1.0                          0.0           0.0   3.0
#
# [5 rows x 82 columns]

# %%
from sksurv.datasets import load_veterans_lung_cancer

data_x, data_y = load_veterans_lung_cancer()
data_y
# Out:
# array([( True,  72.), ( True, 411.), ( True, 228.), ( True, 126.),
#        ( True, 118.), ( True,  10.), ( True,  82.), ( True, 110.),
#        ( True, 314.), (False, 100.), ( True,  42.), ( True,   8.),
#        ( True, 144.), (False,  25.), ( True,  11.), ( True,  30.),
#        ( True, 384.), ( True,   4.), ( True,  54.), ( True,  13.),
#        (False, 123.), (False,  97.), ( True, 153.), ( True,  59.),
#        ( True, 117.), ( True,  16.), ( True, 151.), ( True,  22.),
#        ( True,  56.), ( True,  21.), ( True,  18.), ( True, 139.),
#        ( True,  20.), ( True,  31.), ( True,  52.), ( True, 287.),
#        ( True,  18.), ( True,  51.), ( True, 122.), ( True,  27.),
#        ( True,  54.), ( True,   7.), ( True,  63.), ( True, 392.),
#        ( True,  10.), ( True,   8.), ( True,  92.), ( True,  35.),
#        ( True, 117.), ( True, 132.), ( True,  12.), ( True, 162.),
#        ( True,   3.), ( True,  95.), ( True, 177.), ( True, 162.),
#        ( True, 216.), ( True, 553.), ( True, 278.), ( True,  12.),
#        ( True, 260.), ( True, 200.), ( True, 156.), (False, 182.),
#        ( True, 143.), ( True, 105.), ( True, 103.), ( True, 250.),
#        ( True, 100.), ( True, 999.), ( True, 112.), (False,  87.),
#        (False, 231.), ( True, 242.), ( True, 991.), ( True, 111.),
#        ( True,   1.), ( True, 587.), ( True, 389.), ( True,  33.),
#        ( True,  25.), ( True, 357.), ( True, 467.), ( True, 201.),
#        ( True,   1.), ( True,  30.), ( True,  44.), ( True, 283.),
#        ( True,  15.), ( True,  25.), (False, 103.), ( True,  21.),
#        ( True,  13.), ( True,  87.), ( True,   2.), ( True,  20.),
#        ( True,   7.), ( True,  24.), ( True,  99.), ( True,   8.),
#        ( True,  99.), ( True,  61.), ( True,  25.), ( True,  95.),
#        ( True,  80.), ( True,  51.), ( True,  29.), ( True,  24.),
#        ( True,  18.), (False,  83.), ( True,  31.), ( True,  51.),
#        ( True,  90.), ( True,  52.), ( True,  73.), ( True,   8.),
#        ( True,  36.), ( True,  48.), ( True,   7.), ( True, 140.),
#        ( True, 186.), ( True,  84.), ( True,  19.), ( True,  45.),
#        ( True,  80.), ( True,  52.), ( True, 164.), ( True,  19.),
#        ( True,  53.), ( True,  15.), ( True,  43.), ( True, 340.),
#        ( True, 133.), ( True, 111.), ( True, 231.), ( True, 378.),
#        ( True,  49.)],
#       dtype=[('Status', '?'), ('Survival_in_days', '<f8')])

# %%
import pandas as pd

pd.DataFrame.from_records(data_y[[11, 5, 32, 13, 23]], index=range(1, 6))
# Out:
#    Status  Survival_in_days
# 1    True               8.0
# 2    True              10.0
# 3    True              20.0
# 4   False              25.0
# 5    True              59.0
